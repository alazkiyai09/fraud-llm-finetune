# %% [markdown]
# # 02 Fine-tune QLoRA
#
# Run QLoRA training on Kaggle/Lightning (real path) or local mock smoke path.

# %%
# !python ../src/train.py --config ../configs/qlora_config.yaml --training_config ../configs/training_config.yaml --use_mock_trainer --max_steps 10 --dataset_size 50

# %%
from pathlib import Path
import json

metrics_path = Path('../results/metrics/training_metrics.json')
print(metrics_path.exists())
if metrics_path.exists():
    print(json.loads(metrics_path.read_text(encoding='utf-8')))
