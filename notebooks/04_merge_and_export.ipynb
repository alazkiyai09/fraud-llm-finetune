# %% [markdown]
# # 04 Merge and Export
#
# Merge LoRA adapter with base model and prepare deployment artifacts.

# %%
# !python ../src/merge.py --base_model mistralai/Mistral-7B-Instruct-v0.3 --adapter_path ../results/lora_adapter --output_dir ../results/merged_model --use_mock_merge

# %%
from pathlib import Path

merged = Path('../results/merged_model')
print('exists:', merged.exists())
print('files:', sorted([p.name for p in merged.glob('*')]))
